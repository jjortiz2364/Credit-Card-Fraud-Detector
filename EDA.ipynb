# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV



from sklearn.preprocessing import StandardScaler, RobustScaler

import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # Credit Card Data EDA

# %% [markdown]
# ## Unbalanced Data

# %%
full_credit_data = pd.read_csv('data/creditcard.csv')

# %%
full_credit_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
print(f'Full Credit Card Fraud Dataset Shape: {full_credit_data.shape}')
# Out:
# Full Credit Card Fraud Dataset Shape: (284807, 31)

# %%
print(full_credit_data.columns)
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
print(full_credit_data.isna().sum())
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
non_scaled_data_to_correlate = full_credit_data.drop(['Time', 'Class', 'Amount'], axis=1)
non_scaled_corr_matrix = non_scaled_data_to_correlate.corr()
#non_scaled_corr_matrix

# %%
sb.heatmap(non_scaled_corr_matrix)
plt.show()

# %%
standard_scaler = StandardScaler()
robust_scaler = RobustScaler()

# %%
fully_scaled_df = full_credit_data.copy()

# %%
fully_scaled_df['Scaled_Amount'] = robust_scaler.fit_transform(fully_scaled_df['Amount'].values.reshape(-1,1))
fully_scaled_df['Scaled_Time'] = robust_scaler.fit_transform(fully_scaled_df['Time'].values.reshape(-1,1))

# %%
fully_scaled_df.drop(['Time', 'Amount'], axis=1, inplace=True)

# %%
scaled_time = fully_scaled_df['Scaled_Time']
scaled_amount = fully_scaled_df['Scaled_Amount']

fully_scaled_df.drop(['Scaled_Time', 'Scaled_Amount'], axis=1, inplace=True)

fully_scaled_df.insert(0, 'Scaled_Time', scaled_time)
fully_scaled_df.insert(1, 'Scaled_Amount', scaled_amount)

# %% [markdown]
# **Note: ** We have to make sure we use the subsample in our correlation matrix or else our correlation matrix will be affected by the high imbalance between our classes. This occurs due to the high class imbalance in the original dataframe.

# %%
fully_scaled_df.head()
# Out:
#    Scaled_Time  Scaled_Amount        V1        V2        V3        V4  \
# 0    -0.994983       1.783274 -1.359807 -0.072781  2.536347  1.378155
# 1    -0.994983      -0.269825  1.191857  0.266151  0.166480  0.448154
# 2    -0.994972       4.983721 -1.358354 -1.340163  1.773209  0.379780
# 3    -0.994972       1.418291 -0.966272 -0.185226  1.792993 -0.863291
# 4    -0.994960       0.670579 -1.158233  0.877737  1.548718  0.403034
#
#          V5        V6        V7        V8  ...       V20       V21       V22  \
# 0 -0.338321  0.462388  0.239599  0.098698  ...  0.251412 -0.018307  0.277838
# 1  0.060018 -0.082361 -0.078803  0.085102  ... -0.069083 -0.225775 -0.638672
# 2 -0.503198  1.800499  0.791461  0.247676  ...  0.524980  0.247998  0.771679
# 3 -0.010309  1.247203  0.237609  0.377436  ... -0.208038 -0.108300  0.005274
# 4 -0.407193  0.095921  0.592941 -0.270533  ...  0.408542 -0.009431  0.798278
#
#         V23       V24       V25       V26       V27       V28  Class
# ...

# %%
fully_scaled_df.describe()
# Out:
#          Scaled_Time  Scaled_Amount            V1            V2            V3  \
# count  284807.000000  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05
# mean        0.118914       0.927124  3.918649e-15  5.682686e-16 -8.761736e-15
# std         0.557903       3.495006  1.958696e+00  1.651309e+00  1.516255e+00
# min        -0.994983      -0.307413 -5.640751e+01 -7.271573e+01 -4.832559e+01
# 25%        -0.358210      -0.229162 -9.203734e-01 -5.985499e-01 -8.903648e-01
# 50%         0.000000       0.000000  1.810880e-02  6.548556e-02  1.798463e-01
# 75%         0.641790       0.770838  1.315642e+00  8.037239e-01  1.027196e+00
# max         1.035022     358.683155  2.454930e+00  2.205773e+01  9.382558e+00
#
#                  V4            V5            V6            V7            V8  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   2.811118e-15 -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16
# ...

# %%
scaled_corr_matrix = fully_scaled_df.corr()

# %%
sb.heatmap(scaled_corr_matrix)
plt.show()

# %% [markdown]
# ## UnderSampling

# %%
# Since our classes are highly skewed we should make them equivalent in order to have a normal distribution of the classes.

# Lets shuffle the data before creating the subsamples

df = fully_scaled_df.sample(frac=1)

# amount of fraud classes 492 rows.
fraud_df = df.loc[df['Class'] == 1]
non_fraud_df = df.loc[df['Class'] == 0][:492]

normal_distributed_df = pd.concat([fraud_df, non_fraud_df])

# Shuffle dataframe rows
new_df = normal_distributed_df.sample(frac=1, random_state=42)

new_df.head()
# Out:
#         Scaled_Time  Scaled_Amount         V1         V2         V3  \
# 3175      -0.962688       0.259205  -0.654613   0.969360   1.689934
# 244333     0.794358      -0.293440  -5.222968   4.641827  -8.858204
# 103616    -0.187490       1.117725   1.181839  -1.107988   0.618723
# 154587     0.204678      -0.307413 -28.255053  21.467203 -26.871339
# 42590     -0.511378      -0.233354  -5.932778   4.571743  -9.427247
#
#                V4         V5        V6         V7         V8  ...        V20  \
# 3175     1.055019  -0.491793 -0.006999   0.486224  -0.075069  ...   0.087876
# 244333   7.723502  -1.507035 -2.159484  -4.205164   0.979334  ...  -0.176673
# 103616  -1.771325  -1.808229 -1.355343  -0.526291  -0.301813  ...  -0.255096
# 154587  11.737436 -17.999630  6.065901 -41.506796 -38.987263  ...  10.440718
# 42590    6.577056  -6.115218 -3.661798 -10.894079   3.709210  ...   1.191078
#
#               V21       V22       V23       V24       V25       V26       V27  \
# ...

# %%
print('Distribution of the Classes in the subsample dataset')
print(new_df['Class'].value_counts()/len(new_df))



sb.countplot('Class', data=new_df)
plt.title('Equally Distributed Classes', fontsize=14)
plt.show()
# Out:
# Distribution of the Classes in the subsample dataset
# 0    0.5
# 1    0.5
# Name: Class, dtype: float64
# C:\Users\Jason\AppData\Roaming\Python\Python310\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Make sure we use the subsample in our correlation

f, (ax1, ax2) = plt.subplots(2, 1, figsize=(24,20))

# Entire DataFrame
corr = df.corr()
sb.heatmap(corr, cmap='coolwarm_r', annot_kws={'size':20}, ax=ax1)
ax1.set_title("Imbalanced Correlation Matrix \n (don't use for reference)", fontsize=14)


sub_sample_corr = new_df.corr()
sb.heatmap(sub_sample_corr, cmap='coolwarm_r', annot_kws={'size':20}, ax=ax2)
ax2.set_title('SubSample Correlation Matrix \n (use for reference)', fontsize=14)
plt.show()

# %% [markdown]
# ## OverSampling
